# %%
import pandas as pd

# %%
DB_PATH = "runs_index.csv"

DB = pd.read_csv(DB_PATH, index_col=0)
DB.head()
# Out:
#               collocation_time computer  derivmatch_time  \
# run_dir
# run_0BLmyHm6          0.000000     orcd        29.013032
# run_0CWrKVsW          0.000000     orcd        25.207717
# run_0Gfl62cO         30.977208     orcd         0.000000
# run_0H5EbMNc         16.495440     orcd        29.014588
# run_0ehx44A8        141.590429     orcd        29.398251
#
#                                                        err-file     init  \
# run_dir
# run_0BLmyHm6  /home/txenakis/projects/BVPsolver/logs/array_2...  default
# run_0CWrKVsW  /home/txenakis/projects/BVPsolver/logs/array_2...  default
# run_0Gfl62cO  /home/txenakis/projects/BVPsolver/logs/array_2...  default
# run_0H5EbMNc  /home/txenakis/projects/BVPsolver/logs/array_2...  default
# run_0ehx44A8  /home/txenakis/projects/BVPsolver/logs/array_2...  default
#
#                     model  n_params  ncol  \
# run_dir
# run_0BLmyHm6          mlp       243   0.0
# run_0CWrKVsW  GELU-scaled       188   0.0
# run_0Gfl62cO  GELU-scaled       188   0.0
# run_0H5EbMNc        stiff       318   0.0
# run_0ehx44A8        stiff       816   0.0
#
#                                                        out-file param  ...  \
# run_dir                                                                ...
# run_0BLmyHm6  /home/txenakis/projects/BVPsolver/logs/array_2...  none  ...
# run_0CWrKVsW  /home/txenakis/projects/BVPsolver/logs/array_2...  none  ...
# run_0Gfl62cO  /home/txenakis/projects/BVPsolver/logs/array_2...  none  ...
# run_0H5EbMNc  /home/txenakis/projects/BVPsolver/logs/array_2...  none  ...
# run_0ehx44A8  /home/txenakis/projects/BVPsolver/logs/array_2...  none  ...
#
#              cfg.depth cfg.dm_iters cfg.hidden  cfg.lm_iters  cfg.signed_loss  \
# run_dir
# run_0BLmyHm6         2        10000         12           150            False
# run_0CWrKVsW         2        10000         12           150            False
# run_0Gfl62cO         2        10000         16           150            False
# run_0H5EbMNc         2        10000         12           150            False
# run_0ehx44A8         2        10000         16           150            False
#
#               cfg.linsolve  use_collocation  use_derivmatch shapovalova  \
# run_dir
# run_0BLmyHm6           NaN              NaN             NaN         NaN
# run_0CWrKVsW           NaN              NaN             NaN         NaN
# run_0Gfl62cO           NaN              NaN             NaN         NaN
# run_0H5EbMNc           NaN              NaN             NaN         NaN
# run_0ehx44A8            qr              NaN             NaN         NaN
#
#              shooting
# run_dir
# run_0BLmyHm6      NaN
# run_0CWrKVsW      NaN
# run_0Gfl62cO      NaN
# run_0H5EbMNc      NaN
# run_0ehx44A8      NaN
#
# [5 rows x 32 columns]

# %%
print(DB["model"].unique())
print(DB["problem"].unique())
print(DB["pretraining"].unique())
print(DB["training"].unique())
# Out:
# ['mlp' 'GELU-scaled' 'stiff' nan]
# ['rober' 'orego' 'hires' 'vanderpol' 'pollu' 'davis-skodje']
# ['derivmatch' 'none' nan]
# ['none' 'collocation' 'shooting' 'shapovalova' nan]

# %%
nn = DB[(DB["problem"] == "vanderpol") & (DB["model"] == "stiff") & (DB["pretraining"] == "derivmatch") & (DB["training"] == "collocation")]
nn = DB[(DB["problem"] == "pollu") & (DB["model"] == "stiff") & (DB["pretraining"] == "derivmatch") & (DB["training"] == "collocation")]
nn
# Out:
#               collocation_time computer  derivmatch_time  \
# run_dir
# run_B8TA6bwb       9233.050914     orcd        51.485259
# run_DpEiOWTX       9353.078582     orcd        50.724515
# run_IDVpnloi       8742.292723     orcd        49.624766
# run_fVbSaGWP       4577.776948     orcd        50.078244
# run_xskaaKrJ       9233.955597     orcd        49.015577
#
#                                                        err-file     init  \
# run_dir
# run_B8TA6bwb  /home/txenakis/projects/BVPsolver/logs/array_2...  default
# run_DpEiOWTX  /home/txenakis/projects/BVPsolver/logs/array_2...  default
# run_IDVpnloi  /home/txenakis/projects/BVPsolver/logs/array_2...  default
# run_fVbSaGWP  /home/txenakis/projects/BVPsolver/logs/array_2...  default
# run_xskaaKrJ  /home/txenakis/projects/BVPsolver/logs/array_2...  default
#
#               model  n_params  ncol  \
# run_dir
# run_B8TA6bwb  stiff      4744   0.0
# run_DpEiOWTX  stiff      4744   0.0
# run_IDVpnloi  stiff      4744   0.0
# run_fVbSaGWP  stiff      4744   0.0
# run_xskaaKrJ  stiff      4744   0.0
#
#                                                        out-file param  ...  \
# run_dir                                                                ...
# run_B8TA6bwb  /home/txenakis/projects/BVPsolver/logs/array_2...  none  ...
# run_DpEiOWTX  /home/txenakis/projects/BVPsolver/logs/array_2...  none  ...
# run_IDVpnloi  /home/txenakis/projects/BVPsolver/logs/array_2...  none  ...
# run_fVbSaGWP  /home/txenakis/projects/BVPsolver/logs/array_2...  none  ...
# run_xskaaKrJ  /home/txenakis/projects/BVPsolver/logs/array_2...  none  ...
#
#              cfg.depth cfg.dm_iters cfg.hidden  cfg.lm_iters  cfg.signed_loss  \
# run_dir
# run_B8TA6bwb         3        30000         32           150            False
# run_DpEiOWTX         3        30000         32           150            False
# run_IDVpnloi         3        30000         32           150            False
# run_fVbSaGWP         3        30000         32           150            False
# run_xskaaKrJ         3        30000         32           150            False
#
#               cfg.linsolve  use_collocation  use_derivmatch shapovalova  \
# run_dir
# run_B8TA6bwb           NaN              NaN             NaN         NaN
# run_DpEiOWTX           NaN              NaN             NaN         NaN
# run_IDVpnloi           NaN              NaN             NaN         NaN
# run_fVbSaGWP           NaN              NaN             NaN         NaN
# run_xskaaKrJ           NaN              NaN             NaN         NaN
#
#              shooting
# run_dir
# run_B8TA6bwb      NaN
# run_DpEiOWTX      NaN
# run_IDVpnloi      NaN
# run_fVbSaGWP      NaN
# run_xskaaKrJ      NaN
#
# [5 rows x 32 columns]

# %%
DB.keys()
# Out:
# Index(['collocation_time', 'computer', 'derivmatch_time', 'err-file', 'init',
#        'model', 'n_params', 'ncol', 'out-file', 'param', 'pretraining',
#        'problem', 'profile', 'seed', 'shapovalova_time', 'shoot-iters',
#        'shooting_time', 'sigma', 'timestamp', 'training', 'training_time',
#        'cfg.amr_rounds', 'cfg.depth', 'cfg.dm_iters', 'cfg.hidden',
#        'cfg.lm_iters', 'cfg.signed_loss', 'cfg.linsolve', 'use_collocation',
#        'use_derivmatch', 'shapovalova', 'shooting'],
#       dtype='object')

# %%
vdp1 = DB[(DB["problem"] == "vanderpol") & (DB["seed"] == 123)]
vdp1
# Out:
#               collocation_time computer  derivmatch_time err-file     init  \
# run_dir
# run_9zWKNJ3v               0.0      NaN        13.560064      NaN      NaN
# run_FbGbX3v0               0.0      NaN        12.932799      NaN      NaN
# run_Uve46cZI               0.0      NaN        44.288030      NaN  default
#
#               model  n_params  ncol out-file  param  ... cfg.depth  \
# run_dir                                              ...
# run_9zWKNJ3v    NaN       268   NaN      NaN  100.0  ...         2
# run_FbGbX3v0    NaN       268   NaN      NaN  100.0  ...         2
# run_Uve46cZI  stiff       268   0.0      NaN  100.0  ...         2
#
#              cfg.dm_iters cfg.hidden  cfg.lm_iters  cfg.signed_loss  \
# run_dir
# run_9zWKNJ3v        10000         12           150             True
# run_FbGbX3v0        10000         12           150             True
# run_Uve46cZI        10000         12           150             True
#
#               cfg.linsolve  use_collocation  use_derivmatch shapovalova  \
# run_dir
# run_9zWKNJ3v           NaN            False            True         NaN
# run_FbGbX3v0           NaN            False            True         NaN
# run_Uve46cZI           NaN            False            True       False
#
#              shooting
# run_dir
# run_9zWKNJ3v      NaN
# run_FbGbX3v0      NaN
# run_Uve46cZI    False
#
# [3 rows x 32 columns]
