# %%
import pandas as pd

# %%
DB_PATH = "runs_index.csv"

DB = pd.read_csv(DB_PATH, index_col=0)
DB.head()
# Out:
#               collocation_time  derivmatch_time  n_params  param    problem  \
# run_dir
# run_9zWKNJ3v               0.0        13.560064       268  100.0  vanderpol
# run_FbGbX3v0               0.0        12.932799       268  100.0  vanderpol
#
#              profile  seed  training_time  use_collocation  use_derivmatch  \
# run_dir
# run_9zWKNJ3v    fast   123      13.560064            False            True
# run_FbGbX3v0    fast   123      12.932799            False            True
#
#               cfg.amr_rounds  cfg.depth  cfg.dm_iters  cfg.hidden  \
# run_dir
# run_9zWKNJ3v               1          2         10000          12
# run_FbGbX3v0               1          2         10000          12
#
#               cfg.lm_iters  cfg.signed_loss
# run_dir
# run_9zWKNJ3v           150             True
# run_FbGbX3v0           150             True

# %%
DB.keys()
# Out:
# Index(['collocation_time', 'derivmatch_time', 'n_params', 'param', 'problem',
#        'profile', 'seed', 'training_time', 'use_collocation', 'use_derivmatch',
#        'cfg.amr_rounds', 'cfg.depth', 'cfg.dm_iters', 'cfg.hidden',
#        'cfg.lm_iters', 'cfg.signed_loss'],
#       dtype='object')

# %%
vdp1 = DB[(DB["problem"] == "vanderpol") & (DB["seed"] == 123)]
vdp1
# Out:
#               collocation_time  derivmatch_time  n_params  param    problem  \
# run_dir
# run_9zWKNJ3v               0.0        13.560064       268  100.0  vanderpol
# run_FbGbX3v0               0.0        12.932799       268  100.0  vanderpol
#
#              profile  seed  training_time  use_collocation  use_derivmatch  \
# run_dir
# run_9zWKNJ3v    fast   123      13.560064            False            True
# run_FbGbX3v0    fast   123      12.932799            False            True
#
#               cfg.amr_rounds  cfg.depth  cfg.dm_iters  cfg.hidden  \
# run_dir
# run_9zWKNJ3v               1          2         10000          12
# run_FbGbX3v0               1          2         10000          12
#
#               cfg.lm_iters  cfg.signed_loss
# run_dir
# run_9zWKNJ3v           150             True
# run_FbGbX3v0           150             True
