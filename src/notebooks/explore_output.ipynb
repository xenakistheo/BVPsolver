# %%
using StiffNN, JLD2

data = load("../../data/runs/run_9zWKNJ3v/state.jld2")
ctx  = data["ctx"]
Ydata = ctx.Ydata          # Matrix, size (d, tlen)
# Out:
# 2×151 Matrix{Float64}:
#  2.0   1.99999      1.99997      1.99993     …   1.75457      1.71837
#  0.0  -0.00504769  -0.00609499  -0.00656861     -0.00844106  -0.00879905
